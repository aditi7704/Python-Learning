# %%
1. Create a set with 5 integers and print it.

# %%
s={1,2,3,4,5}
s
# Out:
# {1, 2, 3, 4, 5}

# %%
2. Add an element to a set.

# %%
s={1,2,3}
s.add(4)
s
# Out:
# {1, 2, 3, 4}

# %%
3. Add multiple elements to a set using update().

# %%
s={1,2,3}
s.update({4,5,6})
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
4. Remove an element using remove().

# %%
5. Remove an element using discard() and explain the difference.

# %%
6. Remove and return a random element using pop().

# %%
7. Clear all elements of a set.

# %%
8. Check if a number exists in a set.

# %%
9. Find the length of a set.

# %%
10. Convert a list into a set.

# %%
11. Convert a tuple into a set.

# %%
12.Convert a set into a list.

# %%
13.Create a set from a string and remove duplicates.

# %%
14.Check if two sets are equal.

# %%
15.Iterate through all elements of a set.

# %%
16.Find the maximum element in a set.

# %%
17.Find the minimum element in a set.

# %%
18.Count how many unique values are in a list using a set.

# %%
19.Create a set of squares of numbers from 1 to 10.

# %%
20.Create a set of vowels from a given string.

# %%
21.Find the union of two sets.

# %%
22.Find the intersection of two sets.

# %%
23.Find the difference: elements in set A but not in set B.

# %%
24.Find the symmetric difference of two sets.

# %%
25.Check if a set is subset of another set.

# %%
26.Check if a set is superset of another.

# %%
27.Check if two sets have no elements in common.

# %%
28.Merge two sets without using union().

# %%
29.Remove all duplicates from a list using a set.

# %%
30.Take two lists and find common elements using sets.

# %%
31.Given a list of numbers, print only unique even numbers.

# %%
32.Given a sentence, print all unique words.

# %%
33.Given two strings, check if they have any common character.

# %%
34.Given a set, print the sum of all elements.

# %%
35.Find duplicate elements in a list using a set.

# %%
36.From a list, print elements that appear only once using a set.

# %%
37.Given a list of tuples, extract all unique first elements.

# %%
38.Given a dictionary, print all unique values using a set.

# %%
39.Check if two lists contain the same set of elements.

# %%
40.Create a set of all characters that appear more than once in a string.

# %%
41.Given two sets, remove elements from set A that appear in set B.

# %%
42.Given a list of sets, find the union of all sets.

# %%
43.Given a list of sets, find the intersection of all sets.

# %%
44.Find all subsets (power set) of a given set.

# %%
45.Check if two lists are disjoint using sets.

# %%
46.Given two strings, find uncommon characters (symmetric difference).

# %%
47.Group words by their unique character set (anagram-like using sets).

# %%
48.From a paragraph, return all unique words ignoring punctuation.

# %%
49.Find common elements in three sets.

# %%
50. Check if a set is a “proper subset” of another set.
