# %% [markdown]
# # 1. Create a dictionary and print all its keys.

# %%
d={
    'a':1,
    'b':2,
    'c':3
}
print(d)
print(d.keys())
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# dict_keys(['a', 'b', 'c'])

# %% [markdown]
# # 2. Create a dictionary and print all its values.

# %%
print(d.values())
# Out:
# dict_values([1, 2, 3])

# %% [markdown]
# # 3. Create a dictionary and print all key–value pairs using a loop.

# %%
for i , j in d.items():
    print(i , j)
# Out:
# a 1
# b 2
# c 3

# %% [markdown]
# # 4. Add a new key-value pair to an existing dictionary.

# %%
d.update({'d':4})
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
5. Update the value of an existing key in a dictionary.

# %%
6. Delete a key from a dictionary using `del`.

# %%
7. Delete a key from a dictionary using `pop()`.

# %%
8. Check if a key exists in a dictionary.

# %%
9. Check if a value exists in a dictionary.

# %%
10. Get a value using `get()` and print a default message if the key does not exist.

# %%
11. Count the number of keys in a dictionary.

# %%
12. Create an empty dictionary and add elements using assignment.

# %%
13. Create a dictionary using `dict()` constructor.

# %%
14. Merge two dictionaries.

# %%
15. Clear all items from a dictionary.

# %%
16. Loop through a dictionary and print keys one by one.

# %%
17. Loop through a dictionary and print values one by one.

# %%
18. Loop through a dictionary and print both keys and values.

# %%
19. Convert two lists into a dictionary.

# %%
20. Convert a dictionary into a list of tuples.

# %%
21. Convert a list of tuples into a dictionary.

# %%
22. Create a dictionary with numbers 1–10 as keys and their squares as values.

# %%
23. Create a dictionary with characters of a string as keys and their frequency as values.

# %%
24. Find the key with maximum value in a dictionary.

# %%
25. Find the key with minimum value in a dictionary.

# %%
26. Sort a dictionary by keys.

# %%
27. Sort a dictionary by values.

# %%
28. Print only items where value is even.

# %%
29. Reverse a dictionary (swap keys and values).

# %%
30. Create a nested dictionary and print its items.

# %%
31. Access a specific value inside a nested dictionary.

# %%
32. Update a value inside a nested dictionary.

# %%
33. Delete a key from a nested dictionary.

# %%
34. Create a dictionary from user input (keys & values).

# %%
35. Count occurrences of each word in a sentence using a dictionary.

# %%
36. Combine two dictionaries, adding values of common keys.

# %%
37. Create a dictionary using dictionary comprehension.

# %%
38. Create a dictionary where keys are numbers 1–5 and values are lists.

# %%
39. Remove all keys with value `None`.

# %%
40. Find sum of all values in a dictionary.

# %%
41. Find product of all values in a dictionary.

# %%
42. Group students by marks using a dictionary.

# %%
43. Invert a dictionary where multiple keys may share the same value.

# %%
44. Create a dictionary of word length from a list of words.

# %%
45. Check if two dictionaries are equal.

# %%
46. Count frequency of elements in a list using a dictionary.

# %%
47. Convert a list of dictionaries into a single merged dictionary.

# %%
48. Find common keys between two dictionaries.

# %%
49. Find keys that are only in the first dictionary but not in the second.

# %%
50. Create a dictionary and print it in JSON format.
