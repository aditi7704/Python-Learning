# %%
1. Write a program to check if a number is **positive, negative, or zero**.

# %%
n=int(input("Enter Number:"))
if n > 0:
    print("Positive")
elif n < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter Number: 0
# Zero

# %%
2. Check whether a number is **even or odd**.

# %%
n=int(input("Enter Number:"))
if n % 2 == 0:
      print("Even")
else:
    print("Odd")
# Out:
# Enter Number: 3
# Odd

# %%
3. Check if a given number is **divisible by 5**.

# %%
n=int(input("Enter Number:"))
if n % 5 == 0:
    print("Divisible by 5")
else:
    print("Not Divisible by 5")
# Out:
# Enter Number: 10
# Divisible by 5

# %%
4. Check if a number is **divisible by both 3 and 7**.

# %%
n=int(input("Enter Number:"))
if n % 3 == 0 and n % 7 == 0:
    print("Yes")
else:
    print("No")
# Out:
# Enter Number: 21
# Yes

# %%
5. Write a program to check whether a given year is a **leap year**.

# %%
year=int(input("Enter Leap Year:"))
if year % 4 == 0 and year % 100 !=0:
    print("Leap year")
else:
    print("Not Leap Year")
# Out:
# Enter Leap Year: 2004
# Leap year

# %%
6. Check whether a given character is a **vowel or consonant**.

# %%
ch=input("Enter Character:")
v=['a','e','i','o','u']
if ch in :
    print("Vowels")
else:
    print("consonent")
# Out:
# Enter Character: a
# consonent

# %%
7. Check if the entered character is **uppercase, lowercase, digit, or special character**.

# %%
8. Check if a person is **eligible to vote** (age ≥ 18).

# %%
9. Check whether a number is a **single-digit, double-digit, or triple-digit** number.

# %%
10. Given three sides, check whether they form a **valid triangle**.

# %%
11. Find the **largest of two numbers**.

# %%
12. Find the **largest of three numbers**.

# %%
13. Check if a number is **in the range 1 to 100**.

# %%
14. Check whether a student **passed or failed** (pass if marks ≥ 35).

# %%
15. Given marks, print **grade** (A/B/C/Fail).

# %%
16. Check if the first number is **greater than, less than, or equal to** the second number.

# %%
17. Check if a number is **positive and even**.

# %%
18. Check if a number is **negative and divisible by 3**.

# %%
19. Based on temperature, print **"Cold", "Warm", "Hot"**.

# %%
20. Given a letter, check whether it comes **before or after ‘m’** in alphabetical order.

# %%
21. Check whether two strings are **equal**.

# %%
22. Check whether a string **starts with"hello"**.

# %%
23. Check if a string contains the letter **‘a’**.

# %%
24. Check whether a string has **more vowels or more consonants**.

# %%
25. Check whether the last character of a string is a **digit**.

# %%
26. Check if a given word is a **palindrome**.

# %%
27. Check if the length of a string is **even or odd**.

# %%
28. Check if the first and last characters of a string are **same**.

# %%
29. Check whether a string is **uppercase, lowercase, or mixed**.

# %%
30. Check if a string contains **only alphabets**.

# %%
31. Check if a number is a **perfect square**.

# %%
32. Check if a number is **prime**.

# %%
33. Check whether a number is a **Fibonacci number**.

# %%
34. Check whether the sum of digits of a number is **even or odd**.

# %%
35. Check if a number is a **perfect number**.

# %%
36. Check whether the number is **Armstrong or not**.

# %%
37. Check whether a number ends with digit **5**.

# %%
38. Check if the product of two numbers is **greater than 100**.

# %%
39. Given a number, check whether it is closer to **0 or 100**.

# %%
40. Check if three numbers can form a **Pythagorean triplet**.

# %%
41. Calculate electricity bill based on slabs using **if-elif**.

# %%
42. Check movie ticket price based on **age groups**.

# %%
43. Check if a person is eligible for a **loan** (age, income, credit score).

# %%
44. Given time in 24-hour format, print **Good Morning / Afternoon / Evening / Night**.

# %%
45. Check if a password is **strong** (length ≥ 8 and contains special character).

# %%
46. Check shipping cost: free if amount > 500, else 50.

# %%
47. Check mobile plan validity based on **data usage**.

# %%
48. Validate login using **username and password**.

# %%
49. Print type of triangle: **equilateral / isosceles / scalene**.

# %%
50. Given a month number, print **number of days** (handle February leap-year logic also).
